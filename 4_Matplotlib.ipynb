# %%
import matplotlib.pyplot as plt
import random
#한글폰트 rcparams
plt.style.use('ggplot')

result =[]
for i in range(13):
    result.append(random.randint(1,1000))
print(sorted(result))
plt.boxplot(result)
plt.show()
import numpy as np
result = np.array(result)
print('1/4: '+str(np.percentile(result,25)))
print('2/4: '+str(np.percentile(result,50)))
print('3/4: '+str(np.percentile(result,75)))


plt.barh(['aa','bb','cc','dd','ee,','ff,'],[1,2,3,5,6,7])
plt.show()


color = ['darkmagenta','deeppink','hotpink','pink']
size = [2441,2312,1031,1233]
label = ['A','B','AB','O']
plt.title('A blood type')
plt.pie(size,labels=label, autopct='%.3f%%', colors=color, explode=(0,0.2,0,0.1))
plt.legend(loc=10)
plt.show()

plt.scatter([1,2,3,4],[0.5,2,1,3], s=[30,60,90,120],c=range(4), cmap='RdBu', alpha=1)
plt.colorbar()
# Out:
# [40, 122, 258, 265, 274, 281, 508, 526, 671, 678, 770, 794, 796]
# 1/4: 265.0
# 2/4: 508.0
# 3/4: 678.0

# %%
import csv
import matplotlib.pyplot as plt

f = open('Daejeon_temp.csv','r', encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)

high_temp = []
low_temp = []

for row in data:
    if row[-1]!='' and row[-2]!='':
        date = row[0].split('-')
        if date[1] == '02' and date[2] =='19':
            high_temp.append(float(row[-1]))
            low_temp.append(float(row[-2]))

f.close()

plt.title('2/19 Temperature chage')
plt.plot(high_temp,'red',label='high')
plt.plot(low_temp,'blue',label='low')
plt.legend()
plt.show()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
import matplotlib.pyplot as plt

f = open('Daejeon_temp.csv','r', encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)

Jan = []
Aug = []

for row in data:
    if row[-1] != '':
        date = row[0].split('-')
        if date[1] == '01':
            Jan.append(float(row[-1]))
        if date[1] == '08':
            Aug.append(float(row[-1]))
f.close()

print(max(Aug))
plt.title('Daejeon January and August Highest Temperature Frequency')
plt.hist(Jan,color='b', bins = 10, label = 'Jan')
plt.hist(Aug,color='r', bins = 10, label = 'Aug')
plt.legend()
plt.show()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# 39.4

# %%
import csv
import matplotlib.pyplot as plt

f = open('Daejeon_temp.csv','r', encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)

avg_temp = [[],[],[],[],[],[],[],[],[],[],[],[]]

for row in data:
    if row[2]!='':
        date = row[0].split('-')
        avg_temp[int(date[1])-1].append(float(row[2]))

f.close()

plt.title('Daejeon monthly average temperature distribution')
plt.boxplot(avg_temp)
plt.show()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
import matplotlib.pyplot as plt

f = open('Daejeon_temp.csv','r', encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)

avg_temp = []
for i in range(31):
    avg_temp.append([])

for row in data:
    if row[2]!='':
        date = row[0].split('-')
        if date[1] == '08':
            avg_temp[int(date[2])-1].append(float(row[2]))

f.close()

plt.style.use('ggplot')
plt.figure(figsize=(10,5),dpi=300)
plt.title('Daejeon daily average temperature distribution',fontdict={'fontsize':30, 'fontweight':'light'})
plt.boxplot(avg_temp,showfliers=False)
plt.show()

###############################
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 33
#      30 Jan = []
#      31 Aug = []
# ---> 33 for row in data:
#      34     if row[-1] != '':
#      35         date = row[0].split('-')
#
# ValueError: I/O operation on closed file.

# %%
import csv
import matplotlib.pyplot as plt

f = open('Jeju_temp.csv','r', encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)

high_temp = []
low_temp = []

for row in data:
    if row[-1] != ''and row[-2] !='':
        date = row[0].split('-')
        if date[1]=='02' and date[2]=='19':
            high_temp.append(float(row[-1]))
            low_temp.append(float(row[-2]))


plt.title('Temperature change graph on my birthday')
plt.plot(high_temp, 'r', label='high')
plt.plot(low_temp,'b', label='low')
plt.legend()
plt.show()


##############################################################
Jan = []
Aug = []

f = open('Jeju_temp.csv','r', encoding='cp949')
data = csv.reader(f)
header = next(data)


for row in data:
    if row[-1] != '':
        date = row[0].split('-')
        if date[1] == '01':
            Jan.append(float(row[-1]))
        if date[1] == '08':
            Aug.append(float(row[-1]))
f.close()

plt.title('Jeju January and August Highest Temperature Frequency')
plt.hist(Jan,color='b', bins = 10, label = 'Jan')
plt.hist(Aug,color='r', bins = 10, label = 'Aug')
plt.legend()
plt.show()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
import matplotlib.pyplot as plt

f = open('Jeju_temp.csv','r', encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)

Jan = []
Aug = []

for row in data:
    if row[-1] != '':
        date = row[0].split('-')
        if date[1] == '01':
            Jan.append(float(row[-1]))
        if date[1] == '08':
            Aug.append(float(row[-1]))
f.close()

plt.title('Jeju January and August Highest Temperature Frequency')
plt.hist(Jan,color='b', bins = 10, label = 'Jan')
plt.hist(Aug,color='r', bins = 10, label = 'Aug')
plt.legend()
plt.show()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
import matplotlib.pyplot as plt

f = open('Jeju_temp.csv','r', encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)

avg_temp = [[],[],[],[],[],[],[],[],[],[],[],[]]


for row in data:
    if row[2]!='':
        date = row[0].split('-')
        avg_temp[int(date[1])-1].append(float(row[2]))
f.close()

plt.title('Jeju monthly average temp distribution')
plt.boxplot(avg_temp)
plt.show()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
import matplotlib.pyplot as plt

f = open('Jeju_temp.csv','r', encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)

avg_temp = []
for i in range(31):
    avg_temp.append([])

for row in data:
    if row[2]!='':
        date = row[0].split('-')
        if date[1]=='08':
            avg_temp[int(date[2])-1].append(float(row[2]))

f.close()

plt.figure(figsize=(10,5),dpi=300)
plt.title('Jeju daily average temp distribution')
plt.boxplot(avg_temp,showfliers=False)
plt.show()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

f1 = open('Jeju_temp.csv','r', encoding='cp949')
f2 = open('Daegu_temp.csv','r', encoding='cp949')

data1 = csv.reader(f1)
header1 = next(data1)
print(header)
data2 = csv.reader(f2)
header2 = next(data2)

daily_temp_jeju = []
daily_temp_daegu = []

dail_mean_temp_jeju = []
dail_mean_temp_daegu = []
for i in range(365):
    daily_temp_daegu.append([])
    daily_temp_jeju.append([])

for row1 in data1:
    if row1[2]!='' and row1[0].split('-')[0] !='2025' :
        date = row1[0].split('-')
        if date[1] =='01':
            daily_temp_jeju[int(date[2])-1].append(float(row1[2]))
        elif date[1] =='02':
            if date[2] !='29':
                daily_temp_jeju[int(date[2])-1+31].append(float(row1[2]))
        elif date[1] =='03':
            daily_temp_jeju[int(date[2])-1+59].append(float(row1[2]))
        elif date[1] =='04':
            daily_temp_jeju[int(date[2])-1+90].append(float(row1[2]))
        elif date[1] =='05':
            daily_temp_jeju[int(date[2])-1+120].append(float(row1[2]))
        elif date[1] =='06':
            daily_temp_jeju[int(date[2])-1+151].append(float(row1[2]))
        elif date[1] =='07':
            daily_temp_jeju[int(date[2])-1+181].append(float(row1[2]))
        elif date[1] =='08':
            daily_temp_jeju[int(date[2])-1+212].append(float(row1[2]))
        elif date[1] =='09':
            daily_temp_jeju[int(date[2])-1+243].append(float(row1[2]))
        elif date[1] =='10':
            daily_temp_jeju[int(date[2])-1+273].append(float(row1[2]))
        elif date[1] =='11':
            daily_temp_jeju[int(date[2])-1+304].append(float(row1[2]))
        elif date[1] =='12':
            daily_temp_jeju[int(date[2])-1+334].append(float(row1[2]))

f1.close()


for row2 in data2:
    if row2[2]!='' and row2[0].split('-')[0] !='2025':
        date = row2[0].split('-')
        if date[1] =='01':
            daily_temp_daegu[int(date[2])-1].append(float(row2[2]))
        elif date[1] =='02':
            if date[2] !='29':
                daily_temp_daegu[int(date[2])-1+31].append(float(row2[2]))
        elif date[1] =='03':
            daily_temp_daegu[int(date[2])-1+59].append(float(row2[2]))
        elif date[1] =='04':
            daily_temp_daegu[int(date[2])-1+90].append(float(row2[2]))
        elif date[1] =='05':
            daily_temp_daegu[int(date[2])-1+120].append(float(row2[2]))
        elif date[1] =='06':
            daily_temp_daegu[int(date[2])-1+151].append(float(row2[2]))
        elif date[1] =='07':
            daily_temp_daegu[int(date[2])-1+181].append(float(row2[2]))
        elif date[1] =='08':
            daily_temp_daegu[int(date[2])-1+212].append(float(row2[2]))
        elif date[1] =='09':
            daily_temp_daegu[int(date[2])-1+243].append(float(row2[2]))
        elif date[1] =='10':
            daily_temp_daegu[int(date[2])-1+273].append(float(row2[2]))
        elif date[1] =='11':
            daily_temp_daegu[int(date[2])-1+304].append(float(row2[2]))
        elif date[1] =='12':
            daily_temp_daegu[int(date[2])-1+334].append(float(row2[2]))
f2.close()


for i in range(365):
    a = np.array(daily_temp_daegu[i])
    b = np.array(daily_temp_jeju[i])

    dail_mean_temp_daegu.append(np.mean(a))
    dail_mean_temp_jeju.append(np.mean(b))

import datetime
def time() :
  # 나오게할 날짜 갯수
  numdays = 10
  # 시작될 날짜
  baseDate = datetime.date.today()
  date_list = [baseDate - datetime.timedelta(days=x) for x in range(numdays)]
  print("baseDate: ", baseDate)
  for date in date_list :
    print(date)




plt.title('Jeju / Daegu daily mean Temperature(1969~2024)')
plt.plot(dail_mean_temp_daegu, 'b', label='Daegu')
plt.plot(dail_mean_temp_jeju,'g', label='Jeju')

plt.xticks([0,30,58,89,119,150,180,211,242,272,303,333],labels=['Jan',"Feb",'Mar',"Apr","May",'Jun','Jul',"Aug","Sep","Oct","Nov","Dec"])
plt.legend()
plt.show()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
print(2025-1969+1)
import numpy as np

a = [[1,2,3],[1,2,0]]
a=np.array(a,dtype=object)
print(a.shape)
print(np.mean(a,axis=0))
# Out:
# 57
# (2, 3)
# [1.0 2.0 1.5]
